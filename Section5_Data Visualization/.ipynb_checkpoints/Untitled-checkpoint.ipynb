# %% [markdown]
# SCATTER PLOT

# %%
a<-c(10,13,14,10,12,17)
b<-c(15,17,19,13,13,19)
a
b
# Out:
# [1] 10 13 14 10 12 17
# [1] 15 17 19 13 13 19

# %% [markdown]
# a is X axis and b is Y axis

# %%
plot(a,b)
# Out:
# plot without title

# %% [markdown]
# EXAMPLE:: install.packages("nycflights13")

# %% [markdown]
# library(nycflights13)

# %%
nycflights13::flights
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
# 11     2013 1     1   558      600            -2         849      851
# 12     2013 1     1   558      600            -2         853      856
# ...

# %% [markdown]
# Give attach command, to highlight the row heads

# %%
attach(nycflights13::flights)

# %% [markdown]
# Arr_delay is put on X axis as it is a dependent variable and vice versa

# %%
plot(arr_delay,dep_delay)
# Out:
# plot without title

# %% [markdown]
# TO GIVE TITLE TO THE GRAPH

# %%
plot(arr_delay,dep_delay,main="Arrival vs Departure Delay")
# Out:
# Plot with title "Arrival vs Departure Delay"

# %% [markdown]
# RENAME X AND Y AXIS

# %%
plot(arr_delay,dep_delay,main="Arrival vs Departure Delay", xlab="Arrival Delay", ylab="Departure Delay")
# Out:
# Plot with title "Arrival vs Departure Delay"

# %% [markdown]
# TO DRAW LINES ON PLOT

# %% [markdown]
# First number is y intercept and Second number is slope

# %%
plot(arr_delay,dep_delay, main="Arrival vs Departure Delay", 
     xlab="Arrival Delay", ylab="Departure Delay")
abline(0,1)
abline(0,0)
# Out:
# Plot with title "Arrival vs Departure Delay"

# %% [markdown]
# TO REPLACE CIRCLES WITH OTHER SHAPES

# %% [markdown]
# Changing Plot Character (pch=) 1. Circle 2. Triangle 3. Plus 4. Cross 5. Diamond, 6. Reverese triangle 7. Box and crossed

# %% [markdown]
# Replace circles with shapes as listed above

# %%
plot(arr_delay,dep_delay, main="Arrival vs Departure Delay", 
     xlab="Arrival Delay", ylab="Departure Delay", pch=3)
# Out:
# Plot with title "Arrival vs Departure Delay"

# %% [markdown]
# Replace the circles with character

# %%
plot(arr_delay,dep_delay, main="Arrival vs Departure Delay", 
     xlab="Arrival Delay", ylab="Departure Delay", pch="s")
# Out:
# Plot with title "Arrival vs Departure Delay"

# %% [markdown]
# TO CREATE 2 DIFF PLOTS IN THE SAME CHART EG UNITED AIRLINES (UA) & AMERICAN AIRLINES (AA)

# %% [markdown]
# text, mtext, lines, points can only come after plot command of 1 data

# %%
plot(arr_delay[carrier=="UA"],dep_delay[carrier=="UA"])
points(arr_delay[carrier=="AA"],dep_delay[carrier=="AA"],pch=3)
# Out:
# plot without title

# %%
plot(arr_delay[carrier=="UA"],dep_delay[carrier=="UA"],col="Red")
points(arr_delay[carrier=="AA"],dep_delay[carrier=="AA"],col="Green")
# Out:
# plot without title

# %% [markdown]
# HOW TO PUT GRAPHS SIDE BY SIDE OR ON MULTIPLE PANELS

# %% [markdown]
# mfrow=multiframerow; c=vector combination; 1=no of rows; 2=no of columns (to have UA and AA side by side); if you had 4 graphs then you could have had 2 rows and2 columns or your wish

# %%
par(mfrow=c(1,2))
plot(arr_delay[carrier=="UA"],dep_delay[carrier=="UA"], main="UA")
plot(arr_delay[carrier=="AA"],dep_delay[carrier=="AA"], main="AA")
# Out:
# Plot with title "AA"

# %% [markdown]
# Equal scale for x and y axis.

# %%
par(mfrow=c(1,2))
plot(arr_delay[carrier=="UA"],dep_delay[carrier=="UA"], main="UA", 
     xlim=c(0,1000), ylim=c(0,1000))
plot(arr_delay[carrier=="AA"],dep_delay[carrier=="AA"], main="AA",
     xlim=c(0,1000), ylim=c(0,1000))
# Out:
# Plot with title "AA"

# %% [markdown]
# Restoring the frame for a single plot

# %%
par(mfrow=c(1,1))
plot(arr_delay[carrier=="UA"],dep_delay[carrier=="UA"], main="UA")
# Out:
# Plot with title "UA"
